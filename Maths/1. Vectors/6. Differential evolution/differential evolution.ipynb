# %% [markdown]
# ## Задание
# При фиксированном seed=42 поразбирайтесь и поэкспериментируйте с параметрами алгоритма дифференциальной эволюции: strategy, popsize, tol, mutation, recombination и updating.
#
# Постройте графики количества итераций оптимизации функции ackley от значения параметра.
#
# ### Допзадание
# Найти множество параметров (strategy=..., ..., updating=...), которые требуют минимального количества итераций.

# %%
import numpy as np
from scipy.optimize import differential_evolution

# %%
def ackley(x):
    arg1 = -0.2 * np.sqrt(0.5 * (x[0] ** 2 + x[1] ** 2))
    arg2 = 0.5 * (np.cos(2. * np.pi * x[0]) + np.cos(2. * np.pi * x[1]))
    return -20. * np.exp(arg1) - np.exp(arg2) + 20. + np.e

bounds = [(-10, 10), (-10, 10)]
result = differential_evolution(ackley, bounds, seed=42, strategy='best1bin')
result
# Out:
#      fun: 4.440892098500626e-16
#  message: 'Optimization terminated successfully.'
#     nfev: 2793
#      nit: 90
#  success: True
#        x: array([0., 0.])

# %%
strat = ['best1bin', 'best1exp', 'rand1exp', 'randtobest1exp', 'currenttobest1exp', 'best2exp', 'rand2exp', \
            'randtobest1bin', 'currenttobest1bin', 'best2bin', 'rand2bin', 'rand1bin']
updt = ['immediate', 'deferred']

# %%
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
matplotlib.rcParams['figure.figsize'] = [19, 7]

# %%
ar = []
ar1 = []
ar2 = []
ar3 = []
names = []

for _ in strat:
    ar.append(differential_evolution(ackley, bounds, seed=42, strategy= _, popsize=10, tol=0.01, \
                                      mutation=1, recombination=0.5, updating=i)['nit'])
    ar1.append(differential_evolution(ackley, bounds, seed=42, strategy= _, popsize=20, tol=0.01, \
                                      mutation=1, recombination=0.5, updating=i)['nit'])
    ar2.append(differential_evolution(ackley, bounds, seed=42, strategy= _, popsize=5, tol=0.01, \
                                      mutation=1, recombination=0.5, updating=i)['nit'])
    ar3.append(differential_evolution(ackley, bounds, seed=42, strategy= _, popsize=3, tol=0.01, \
                                      mutation=1, recombination=0.5, updating=i)['nit'])
    names.append(_)

plt.plot(names, ar)
plt.plot(names, ar1)
plt.plot(names, ar2)
plt.plot(names, ar3)
plt.grid()
plt.legend(labels=['popsize=10', 'popsize=20', 'popsize=5', 'popsize=3'], loc=2, fontsize=15)
plt.show()

# %% [markdown]
# Параметр popsize выберем равным 5

# %%
ar = []
ar1 = []
ar2 = []
ar3 = []
names = []

for _ in strat:
    ar.append(differential_evolution(ackley, bounds, seed=42, strategy= _, popsize=5, tol=0.01, \
                                      mutation=1, recombination=0.5, updating=i)['nit'])
    ar1.append(differential_evolution(ackley, bounds, seed=42, strategy= _, popsize=5, tol=0.05, \
                                      mutation=1, recombination=0.5, updating=i)['nit'])
    ar2.append(differential_evolution(ackley, bounds, seed=42, strategy= _, popsize=5, tol=0.1, \
                                      mutation=1, recombination=0.5, updating=i)['nit'])
    ar3.append(differential_evolution(ackley, bounds, seed=42, strategy= _, popsize=5, tol=0.5, \
                                      mutation=1, recombination=0.5, updating=i)['nit'])
    names.append(_)
plt.plot(names, ar)
plt.plot(names, ar1)
plt.plot(names, ar2)
plt.plot(names, ar3)
plt.grid()
plt.legend(labels=['tol=0.01', 'tol=0.05', 'tol=0.1', 'tol=0.5'], loc=2, fontsize=15)
plt.show()

# %% [markdown]
# Параметр чувствительности не будем оптимизировать в последствии, оставим равным 0.01

# %%
ar = []
ar1 = []
ar2 = []
ar3 = []
names = []

for _ in strat:
    ar.append(differential_evolution(ackley, bounds, seed=42, strategy= _, popsize=5, tol=0.01, \
                                      mutation=1, recombination=0.05, updating=i)['nit'])
    ar1.append(differential_evolution(ackley, bounds, seed=42, strategy= _, popsize=5, tol=0.01, \
                                      mutation=1, recombination=0.1, updating=i)['nit'])
    ar2.append(differential_evolution(ackley, bounds, seed=42, strategy= _, popsize=5, tol=0.01, \
                                      mutation=1, recombination=0.5, updating=i)['nit'])
    ar3.append(differential_evolution(ackley, bounds, seed=42, strategy= _, popsize=5, tol=0.01, \
                                      mutation=1, recombination=1, updating=i)['nit'])
    names.append(_)
plt.plot(names, ar)
plt.plot(names, ar1)
plt.plot(names, ar2)
plt.plot(names, ar3)
plt.grid()
plt.legend(labels=['recombination=0.05', 'recombination=0.1', 'recombination=0.5', 'recombination=1'], loc=2, fontsize=15)
plt.show()

# %% [markdown]
# Параметр recombination выберем равным 1

# %%
ar = []
ar1 = []
ar2 = []
ar3 = []
names = []

for _ in strat:
    ar.append(differential_evolution(ackley, bounds, seed=42, strategy= _, popsize=5, tol=0.01, \
                                      mutation=0.5, recombination=1, updating=i)['nit'])
    ar1.append(differential_evolution(ackley, bounds, seed=42, strategy= _, popsize=5, tol=0.01, \
                                      mutation=1, recombination=1, updating=i)['nit'])
    ar2.append(differential_evolution(ackley, bounds, seed=42, strategy= _, popsize=5, tol=0.01, \
                                      mutation=1.5, recombination=1, updating=i)['nit'])
    ar3.append(differential_evolution(ackley, bounds, seed=42, strategy= _, popsize=5, tol=0.01, \
                                      mutation=1.99, recombination=1, updating=i)['nit'])
    names.append(_)
plt.plot(names, ar)
plt.plot(names, ar1)
plt.plot(names, ar2)
plt.plot(names, ar3)
plt.grid()
plt.legend(labels=['mutation=0.5', 'mutation=1', 'mutation=1.5', 'mutation=1.99'], loc=2, fontsize=15)
plt.show()

# %% [markdown]
# Параметр mutation выберем равным 1

# %% [markdown]
# Графики выше строились с параметром updating = 'immediate'
# Сравним его выбрав значение 'deferred' и выберем алгоритм, требующий минимум итераций, предположим, что все прочие параметры в случае с 'deffered' оказывали бы такое же влияние на кол-во итераций

# %%
ar = []
ar1 = []
names = []

for _ in strat:
    ar.append(differential_evolution(ackley, bounds, seed=42, strategy= _, popsize=5, tol=0.01, \
                                      mutation=1, recombination=1, updating='immediate')['nit'])
    ar1.append(differential_evolution(ackley, bounds, seed=42, strategy= _, popsize=5, tol=0.01, \
                                      mutation=1, recombination=1, updating='deferred')['nit'])
    names.append(_)
    
plt.plot(names, ar)
plt.plot(names, ar1)
plt.grid()
plt.legend(labels=['updating=immediate', 'updating=deferred'], loc=2, fontsize=15)
plt.show()

# %% [markdown]
# Выбираем настройку 'updating=immediate', посторим график для методов с самыми маленькими значениями

# %%
strat = ['best1bin', 'best1exp', 'randtobest1exp', 'currenttobest1exp', 'randtobest1bin', 'currenttobest1bin']

# %%
ar = []

names = []

for _ in strat:
    ar.append(differential_evolution(ackley, bounds, seed=42, strategy= _, popsize=5, tol=0.01, \
                                      mutation=1, recombination=1, updating='immediate')['nit'])

    names.append(_)
    
plt.plot(names, ar)
plt.grid()
plt.legend(labels=['updating=immediate'], loc=2, fontsize=15)
plt.show()

# %% [markdown]
# Методы best1bin, best1exp, randtobest1exp, currenttobest1bin, при настройке параметра updating=immediate
# выполняются с наименьшим количеством итераций nit = 9
